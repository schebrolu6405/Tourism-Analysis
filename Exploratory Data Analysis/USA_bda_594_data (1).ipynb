# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("C:/Users/jshaik2452/Downloads/Cleaned Datasets/Cleaned Datasets/USA bda 594 data.xlsx")

# %%
df.head()
# Out:
#            Basic data and indicators Region            Category      Units  \
# 0     Overnights visitors (tourists)    USA            Arrivals  Thousands
# 1  Same-day visitors (excursionists)    USA            Arrivals  Thousands
# 2                     Total arrivals    USA            Arrivals  Thousands
# 3                             Africa    USA  Arrivals by region  Thousands
# 4                           Americas    USA  Arrivals by region  Thousands
#
#   Notes Series       1995       1996      1997       1998  ...        2012  \
# 0    1/     TF      43318      46489     47767      46377  ...   66966.897
# 1    2/    NaN      36414      36267     34758      28390  ...      104663
# 2   NaN     VF      79732      82756     82525      74767  ...  171629.897
# 3   NaN    NaN    138.774    204.291   233.972    258.228  ...     381.082
# 4   NaN    NaN  26542.674  27924.242  28132.79  27494.232  ...   43168.319
#
# ...

# %%
len(df)
# Out:
# 49

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Basic data and indicators  49 non-null     object
#  1   Region                     49 non-null     object
#  2   Category                   49 non-null     object
#  3   Units                      48 non-null     object
#  4   Notes                      17 non-null     object
#  5   Series                     34 non-null     object
#  6   1995                       48 non-null     object
#  7   1996                       48 non-null     object
#  8   1997                       48 non-null     object
#  9   1998                       48 non-null     object
#  10  1999                       48 non-null     object
#  11  2000                       48 non-null     object
#  12  2001                       48 non-null     object
# ...

# %%
df.describe()
# Out:
#        Basic data and indicators Region            Category      Units Notes  \
# count                         49     49                  49         48    17
# unique                        35      1                  12          5     5
# top                        Total    USA  Arrivals by region  Thousands    1/
# freq                           7     49                   9         36     8
#
#        Series 1995 1996 1997 1998  ... 2012 2013 2014 2015 2016 2017 2018  \
# count      34   48   48   48   48  ...   48   48   48   48   48   48   48
# unique      8   27   29   40   40  ...   38   39   39   39   39   39   39
# top        ..   ..   ..   ..   ..  ...   ..   ..   ..   ..   ..   ..   ..
# freq       19   22   20    9    9  ...    9    9    9    9    9    9    9
#
#        2019 2020     2021
# count    48   48     25.0
# unique   39   27     23.0
# top      ..   ..  22100.4
# freq      9   20      2.0
#
# [4 rows x 33 columns]

# %%
df.isnull().sum()
# Out:
# Basic data and indicators     0
# Region                        0
# Category                      0
# Units                         1
# Notes                        32
# Series                       15
# 1995                          1
# 1996                          1
# 1997                          1
# 1998                          1
# 1999                          1
# 2000                          1
# 2001                          1
# 2002                          1
# 2003                          1
# 2004                          1
# 2005                          1
# 2006                          1
# 2007                          1
# 2008                          1
# 2009                          1
# 2010                          1
# 2011                          1
# 2012                          1
# 2013                          1
# 2014                          1
# 2015                          1
# 2016                          1
# 2017                          1
# ...

# %%
print(df[2012])
# Out:
# 0        66966.897
# 1           104663
# 2       171629.897
# 3          381.082
# 4        43168.319
# 5         8941.989
# 6        13137.646
# 7          485.555
# 8          852.306
# 9               ..
# 10              ..
# 11       66966.897
# 12    23936.442768
# 13     6134.465232
# 14       30070.908
# 15       37752.463
# 16         449.587
# 17       28764.847
# 18       66966.897
# 19              ..
# 20              ..
# 21             NaN
# 22    26411.922768
# 23    256195.65085
# 24          153921
# 25           41192
# 26          195113
# 27         2059600
# 28              ..
# 29              ..
# 30           61344
# 31           57094
# 32          118968
# 33           90340
# 34           47827
# 35          138167
# 36           52643
# 37         4926543
# 38              ..
# 39              ..
# 40            62.2
# 41              ..
# 42     1400.241036
# 43       15.255398
# 44     1563.613082
# 45     1028.560907
# 46      181.435494
# ...

# %%
print(df[2021].dtype)
# Out:
# object

# %%
# List of columns to convert
columns_to_convert = [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

# %%
# Convert specified columns to numeric
df[columns_to_convert] = df[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Basic data and indicators  49 non-null     object
#  1   Region                     49 non-null     object
#  2   Category                   49 non-null     object
#  3   Units                      48 non-null     object
#  4   Notes                      17 non-null     object
#  5   Series                     34 non-null     object
#  6   1995                       26 non-null     float64
#  7   1996                       28 non-null     float64
#  8   1997                       39 non-null     float64
#  9   1998                       39 non-null     float64
#  10  1999                       38 non-null     float64
#  11  2000                       39 non-null     float64
#  12  2001                       39 non-null     float64
# ...

# %%
df.head()
# Out:
#            Basic data and indicators Region            Category      Units  \
# 0     Overnights visitors (tourists)    USA            Arrivals  Thousands
# 1  Same-day visitors (excursionists)    USA            Arrivals  Thousands
# 2                     Total arrivals    USA            Arrivals  Thousands
# 3                             Africa    USA  Arrivals by region  Thousands
# 4                           Americas    USA  Arrivals by region  Thousands
#
#   Notes Series       1995       1996       1997       1998  ...        2012  \
# 0    1/     TF  43318.000  46489.000  47767.000  46377.000  ...   66966.897
# 1    2/    NaN  36414.000  36267.000  34758.000  28390.000  ...  104663.000
# 2   NaN     VF  79732.000  82756.000  82525.000  74767.000  ...  171629.897
# 3   NaN    NaN    138.774    204.291    233.972    258.228  ...     381.082
# 4   NaN    NaN  26542.674  27924.242  28132.790  27494.232  ...   43168.319
#
# ...

# %%
df.isnull().sum()
# Out:
# Basic data and indicators     0
# Region                        0
# Category                      0
# Units                         1
# Notes                        32
# Series                       15
# 1995                         23
# 1996                         21
# 1997                         10
# 1998                         10
# 1999                         11
# 2000                         10
# 2001                         10
# 2002                         10
# 2003                         10
# 2004                         10
# 2005                         10
# 2006                          9
# 2007                          9
# 2008                          9
# 2009                          9
# 2010                          9
# 2011                         10
# 2012                         10
# 2013                         10
# 2014                         10
# 2015                         10
# 2016                         10
# 2017                         10
# ...

# %%
df = df.drop(['Region','Units','Notes','Series'],axis=1)

# %%
df.head()
# Out:
#            Basic data and indicators            Category       1995  \
# 0     Overnights visitors (tourists)            Arrivals  43318.000
# 1  Same-day visitors (excursionists)            Arrivals  36414.000
# 2                     Total arrivals            Arrivals  79732.000
# 3                             Africa  Arrivals by region    138.774
# 4                           Americas  Arrivals by region  26542.674
#
#         1996       1997       1998       1999       2000       2001  \
# 0  46489.000  47767.000  46377.000  48689.000  51238.000  46927.000
# 1  36267.000  34758.000  28390.000  27107.000  27105.000  24048.000
# 2  82756.000  82525.000  74767.000  75796.000  78343.000  70975.000
# 3    204.291    233.972    258.228    272.798    295.090    286.783
# 4  27924.242  28132.790  27494.232  28764.295  30357.382  29597.630
#
#         2002  ...        2012        2013        2014        2015        2016  \
# ...

# %%
df = df[~df['Basic data and indicators'].str.contains('Total', case=False, na=False)]
df = df.dropna()

# %%
columns_to_drop = [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002]
df = df.drop(columns_to_drop, axis=1)

# %%
df.head()
# Out:
#            Basic data and indicators            Category       2003  \
# 0     Overnights visitors (tourists)            Arrivals  41218.000
# 1  Same-day visitors (excursionists)            Arrivals  20864.000
# 3                             Africa  Arrivals by region    236.067
# 4                           Americas  Arrivals by region  26368.034
# 5          East Asia and the Pacific  Arrivals by region   5192.366
#
#         2004       2005        2006        2007        2008        2009  \
# 0  46086.000  49206.000   50977.000   56135.000   58007.000   55103.000
# 1  21520.000  22278.000  132201.000  119164.000  117696.000  105405.000
# 3    240.488    251.654     251.841     276.300     311.136     290.861
# 4  29195.347  31178.835   33128.595   36619.652   37198.161   36052.067
# 5   6086.708   6518.211    6427.817    6562.889    6343.399    5905.954
#
#          2010  ...        2012        2013        2014       2015       2016  \
# ...

# %%
# columns_to_fill = [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
# df[columns_to_fill] = df[columns_to_fill].fillna(df[columns_to_fill].mean())

# %%
df.head()
# Out:
#            Basic data and indicators            Category       2003  \
# 0     Overnights visitors (tourists)            Arrivals  41218.000
# 1  Same-day visitors (excursionists)            Arrivals  20864.000
# 3                             Africa  Arrivals by region    236.067
# 4                           Americas  Arrivals by region  26368.034
# 5          East Asia and the Pacific  Arrivals by region   5192.366
#
#         2004       2005        2006        2007        2008        2009  \
# 0  46086.000  49206.000   50977.000   56135.000   58007.000   55103.000
# 1  21520.000  22278.000  132201.000  119164.000  117696.000  105405.000
# 3    240.488    251.654     251.841     276.300     311.136     290.861
# 4  29195.347  31178.835   33128.595   36619.652   37198.161   36052.067
# 5   6086.708   6518.211    6427.817    6562.889    6343.399    5905.954
#
#          2010  ...        2012        2013        2014       2015       2016  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.corr()
# Out:
# C:\Users\jshaik2452\AppData\Local\Temp\ipykernel_19096\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           2003      2004      2005      2006      2007      2008      2009  \
# 2003  1.000000  0.999494  0.999427  0.722873  0.801368  0.826666  0.849515
# 2004  0.999494  1.000000  0.999778  0.708893  0.788889  0.814750  0.838088
# 2005  0.999427  0.999778  1.000000  0.703668  0.784775  0.811601  0.834865
# 2006  0.722873  0.708893  0.703668  1.000000  0.992241  0.983592  0.977087
# 2007  0.801368  0.788889  0.784775  0.992241  1.000000  0.997897  0.995746
# 2008  0.826666  0.814750  0.811601  0.983592  0.997897  1.000000  0.998659
# 2009  0.849515  0.838088  0.834865  0.977087  0.995746  0.998659  1.000000
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
for i in df:
    if df[i].dtype == object:
        df[i] = label_encoder.fit_transform(df[i])

# %%
df.head()
# Out:
#    Basic data and indicators  Category       2003       2004       2005  \
# 0                          7         0  41218.000  46086.000  49206.000
# 1                          9         0  20864.000  21520.000  22278.000
# 3                          0         2    236.067    240.488    251.654
# 4                          2         2  26368.034  29195.347  31178.835
# 5                          3         2   5192.366   6086.708   6518.211
#
#          2006        2007        2008        2009        2010  ...  \
# 0   50977.000   56135.000   58007.000   55103.000   60010.000  ...
# 1  132201.000  119164.000  117696.000  105405.000  102265.000  ...
# 3     251.841     276.300     311.136     290.861     311.205  ...
# 4   33128.595   36619.652   37198.161   36052.067   38859.223  ...
# 5    6427.817    6562.889    6343.399    5905.954    7369.149  ...
#
#          2012        2013        2014       2015       2016       2017  \
# ...

# %%
correlation_mat = df.corr()
corr_pairs = correlation_mat.unstack()
sorted_pairs = corr_pairs.sort_values(kind="quicksort")
#print(sorted_pairs)
strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]
print(strong_pairs)
print()
plt.figure(figsize=(20, 8))
sns.heatmap(correlation_mat, annot = True)
plt.show()
# Out:
# 2006  2005    0.703668
# 2005  2006    0.703668
# 2004  2006    0.708893
# 2006  2004    0.708893
#       2003    0.722873
#                 ...
# 2016  2016    1.000000
# 2017  2017    1.000000
# 2018  2018    1.000000
# 2010  2010    1.000000
# 2021  2021    1.000000
# Length: 363, dtype: float64
