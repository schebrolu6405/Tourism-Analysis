# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/jshaik2452/Downloads/Cleaned Datasets/Cleaned Datasets/Trips_by_Distance in CA.csv')

# %%
df.head()
# Out:
#   Unnamed: 0      Date  State FIPS State Postal Code  County FIPS County Name  \
# 0   National  1/1/2019         NaN               NaN          NaN         NaN
# 1   National  1/2/2019         NaN               NaN          NaN         NaN
# 2   National  1/3/2019         NaN               NaN          NaN         NaN
# 3   National  1/4/2019         NaN               NaN          NaN         NaN
# 4   National  1/5/2019         NaN               NaN          NaN         NaN
#
#    Population Staying at Home  Population Not Staying at Home  \
# 0                  77433867.0                     248733553.0
# 1                  61305201.0                     264862219.0
# 2                  63050480.0                     263116940.0
# 3                  61803652.0                     264363768.0
# 4                  64389745.0                     261777675.0
#
#    Number of Trips  Number of Trips <1  ...  Number of Trips 5-10  \
# ...

# %%
df.shape
# Out:
# (1048575, 22)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                            0
# Date                                  0
# State FIPS                          901
# State Postal Code                   901
# County FIPS                       46852
# County Name                       46852
# Population Staying at Home        12950
# Population Not Staying at Home    12950
# Number of Trips                   12950
# Number of Trips <1                12950
# Number of Trips 1-3               12950
# Number of Trips 3-5               12950
# Number of Trips 5-10              12950
# Number of Trips 10-25             12950
# Number of Trips 25-50             12950
# Number of Trips 50-100            12950
# Number of Trips 100-250           12950
# Number of Trips 250-500           12950
# Number of Trips >=500             12950
# Row ID                                0
# Week                                  0
# Month                                 0
# dtype: int64

# %%
df = df.drop(columns = 'Row ID', axis=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'State FIPS', 'State Postal Code', 'County FIPS',
#        'County Name', 'Population Staying at Home',
#        'Population Not Staying at Home', 'Number of Trips',
#        'Number of Trips <1', 'Number of Trips 1-3', 'Number of Trips 3-5',
#        'Number of Trips 5-10', 'Number of Trips 10-25',
#        'Number of Trips 25-50', 'Number of Trips 50-100',
#        'Number of Trips 100-250', 'Number of Trips 250-500',
#        'Number of Trips >=500', 'Week', 'Month'],
#       dtype='object')

# %%
df.describe()
# Out:
#          State FIPS   County FIPS  Population Staying at Home  \
# count  1.047674e+06  1.001723e+06                1.035625e+06
# mean   3.021900e+01  3.038029e+04                1.462917e+05
# std    1.516822e+01  1.516011e+04                2.225797e+06
# min    1.000000e+00  1.001000e+03                8.000000e+00
# 25%    1.800000e+01  1.817700e+04                2.079000e+03
# 50%    2.900000e+01  2.917500e+04                5.018000e+03
# 75%    4.500000e+01  4.508100e+04                1.595000e+04
# max    5.600000e+01  5.604500e+04                1.102118e+08
#
#        Population Not Staying at Home  Number of Trips  Number of Trips <1  \
# count                    1.035625e+06     1.035625e+06        1.035625e+06
# mean                     5.234714e+05     2.477794e+06        6.120798e+05
# std                      7.649900e+06     3.618162e+07        9.003866e+06
# min                      8.700000e+01     2.200000e+02        0.000000e+00
# ...

# %%
for i in df:
    if df[i].dtype == object:
        print(df[i].value_counts())
# Out:
# County      1001723
# State         45951
# National        901
# Name: Unnamed: 0, dtype: int64
# 1/1/2019     3194
# 7/30/2019    3194
# 8/6/2019     3194
# 8/5/2019     3194
# 8/4/2019     3194
#              ...
# 5/29/2020      52
# 5/30/2020      52
# 5/31/2020      52
# 3/27/2020      52
# 2/6/2022       40
# Name: Date, Length: 903, dtype: int64
# TX    81859
# GA    51623
# VA    43314
# KY    39181
# MO    37527
# KS    34408
# IL    33439
# NC    32732
# IA    32523
# TN    31202
# NE    30569
# IN    30249
# OH    28962
# MN    28606
# MI    27355
# MS    27027
# OK    25426
# AR    24829
# WI    23856
# AL    22256
# FL    22243
# PA    22231
# SD    21929
# CO    21328
# LA    21287
# NY    20661
# CA    19363
# MT    18804
# WV    18410
# ND    17842
# SC    15574
# ID    14937
# WA    13339
# OR    12385
# NM    11435
# AK    10169
# UT    10126
# MD     8546
# WY     8238
# NJ     7600
# NV     6308
# ME     6005
# AZ     5675
# VT     5353
# MA     5353
# ...

# %%
for i in df:
    if df[i].dtype == object:
        if df[i].isnull().sum() < 75*len(df[i]):
            df[i].fillna(df[i].mode()[0],inplace=True)
            df[i] = df[i].astype('string')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Unnamed: 0                      1048575 non-null  string
#  1   Date                            1048575 non-null  string
#  2   State FIPS                      1047674 non-null  float64
#  3   State Postal Code               1048575 non-null  string
#  4   County FIPS                     1001723 non-null  float64
#  5   County Name                     1048575 non-null  string
#  6   Population Staying at Home      1035625 non-null  float64
#  7   Population Not Staying at Home  1035625 non-null  float64
#  8   Number of Trips                 1035625 non-null  float64
#  9   Number of Trips <1              1035625 non-null  float64
#  10  Number of Trips 1-3             1035625 non-null  float64
# ...

# %%
from pandas.api.types import is_numeric_dtype
from pandas.api.types import is_float_dtype
for i in df:
    if is_float_dtype(df[i]):
        if df[i].isnull().sum() < 75*len(df[i]):
            df[i].fillna(df[i].mean(),inplace=True)
            df[i]=pd.to_numeric(df[i], errors = 'coerce')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                        0
# Date                              0
# State FIPS                        0
# State Postal Code                 0
# County FIPS                       0
# County Name                       0
# Population Staying at Home        0
# Population Not Staying at Home    0
# Number of Trips                   0
# Number of Trips <1                0
# Number of Trips 1-3               0
# Number of Trips 3-5               0
# Number of Trips 5-10              0
# Number of Trips 10-25             0
# Number of Trips 25-50             0
# Number of Trips 50-100            0
# Number of Trips 100-250           0
# Number of Trips 250-500           0
# Number of Trips >=500             0
# Week                              0
# Month                             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Unnamed: 0                      1048575 non-null  string
#  1   Date                            1048575 non-null  string
#  2   State FIPS                      1048575 non-null  float64
#  3   State Postal Code               1048575 non-null  string
#  4   County FIPS                     1048575 non-null  float64
#  5   County Name                     1048575 non-null  string
#  6   Population Staying at Home      1048575 non-null  float64
#  7   Population Not Staying at Home  1048575 non-null  float64
#  8   Number of Trips                 1048575 non-null  float64
#  9   Number of Trips <1              1048575 non-null  float64
#  10  Number of Trips 1-3             1048575 non-null  float64
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dropna(subset=['Date'], inplace = True)

# %%
df.shape
# Out:
# (1048575, 21)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'State FIPS', 'State Postal Code', 'County FIPS',
#        'County Name', 'Population Staying at Home',
#        'Population Not Staying at Home', 'Number of Trips',
#        'Number of Trips <1', 'Number of Trips 1-3', 'Number of Trips 3-5',
#        'Number of Trips 5-10', 'Number of Trips 10-25',
#        'Number of Trips 25-50', 'Number of Trips 50-100',
#        'Number of Trips 100-250', 'Number of Trips 250-500',
#        'Number of Trips >=500', 'Week', 'Month'],
#       dtype='object')

# %%
df['Week'].value_counts()
# Out:
# 24    45080
# 23    45080
# 6     23126
# 21    23086
# 13    23086
# 1     23086
# 22    23086
# 20    23086
# 19    23086
# 18    23086
# 17    23086
# 15    23086
# 14    23086
# 16    23086
# 12    23086
# 7     23086
# 2     23086
# 3     23086
# 11    23086
# 5     23086
# 4     23086
# 8     23086
# 9     23086
# 10    23086
# 25    23030
# 41    22722
# 34    22722
# 40    22722
# 39    22722
# 38    22722
# 37    22722
# 36    22722
# 35    22722
# 26    22722
# 33    22722
# 32    22722
# 31    22722
# 30    22722
# 29    22722
# 28    22722
# 27    22722
# 42    22722
# 43    18448
# 0     16282
# 44      906
# 45      758
# 47      729
# 46      728
# 48      728
# 49      728
# 50      728
# 51      728
# 52      416
# Name: Week, dtype: int64

# %%
df['Date'].head()
# Out:
# 0   2019-01-01
# 1   2019-01-02
# 2   2019-01-03
# 3   2019-01-04
# 4   2019-01-05
# Name: Date, dtype: datetime64[ns]

# %%
df['total population'] = df['Population Staying at Home']+df['Population Not Staying at Home']

# %%
df['total population'].head()
# Out:
# 0    326167420.0
# 1    326167420.0
# 2    326167420.0
# 3    326167420.0
# 4    326167420.0
# Name: total population, dtype: float64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'State FIPS', 'State Postal Code', 'County FIPS',
#        'County Name', 'Population Staying at Home',
#        'Population Not Staying at Home', 'Number of Trips',
#        'Number of Trips <1', 'Number of Trips 1-3', 'Number of Trips 3-5',
#        'Number of Trips 5-10', 'Number of Trips 10-25',
#        'Number of Trips 25-50', 'Number of Trips 50-100',
#        'Number of Trips 100-250', 'Number of Trips 250-500',
#        'Number of Trips >=500', 'Week', 'Month', 'total population'],
#       dtype='object')

# %%
 for col in df.columns:
        if is_numeric_dtype(df[col]):
            print('Working on column: {}'.format(col))
            mean = df[col].mean()
            sd = df[col].std()
            df = df[(df[col] <= mean+(3*sd))]
# Out:
# Working on column: State FIPS
# Working on column: County FIPS
# Working on column: Population Staying at Home
# Working on column: Population Not Staying at Home
# Working on column: Number of Trips
# Working on column: Number of Trips <1
# Working on column: Number of Trips 1-3
# Working on column: Number of Trips 3-5
# Working on column: Number of Trips 5-10
# Working on column: Number of Trips 10-25
# Working on column: Number of Trips 25-50
# Working on column: Number of Trips 50-100
# Working on column: Number of Trips 100-250
# Working on column: Number of Trips 250-500
# Working on column: Number of Trips >=500
# Working on column: Week
# Working on column: Month
# Working on column: total population

# %%
df.shape
# Out:
# (772663, 22)

# %%
df.corr()
# Out:
# C:\Users\jshaik2452\AppData\Local\Temp\ipykernel_14380\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                 State FIPS  County FIPS  \
# State FIPS                        1.000000     0.999975
# County FIPS                       0.999975     1.000000
# Population Staying at Home        0.046262     0.045953
# Population Not Staying at Home    0.036190     0.035935
# Number of Trips                   0.039090     0.038763
# Number of Trips <1                0.038574     0.038515
# Number of Trips 1-3               0.034767     0.034543
# Number of Trips 3-5               0.031256     0.030886
# Number of Trips 5-10              0.026868     0.026476
# Number of Trips 10-25             0.040698     0.040145
# ...

# %%
df.to_csv('C:/Users/jshaik2452/Downloads/Cleaned Datasets/EDA completed datasets/Trip by distance.csv', index=False)

# %%
df.head(10)

# %%
pip install plotly

# %%
plt.figure(figsize=(10, 6))
df['Number of Trips'].plot(kind='hist', bins=20, edgecolor='black')
plt.title('Number of Trips Distribution')
plt.xlabel('Number of Trips')
plt.ylabel('Frequency')
plt.show()
